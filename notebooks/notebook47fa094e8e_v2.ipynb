# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/unseen-data/PXL_20250208_1229178382.jpg
# /kaggle/input/unseen-data/images.jpg
# /kaggle/input/skindiseasedataset/Readme.md
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/dermatofibroma-103.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/calcifying-epithelioma-7.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/epidermal-cyst-147.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/dermatofibroma-117.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/porokeratosis-70.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/skin-tags-polyps-44.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/acquired-digital-fibrokeratoma-3.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/connective-tissue-nevus-1.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/kyrle-disease-7.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/keloids-71.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/nevus-sebaceous-23.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/nevus-sebaceous-37.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/spiny-keratoderma-6.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/keratoacanthoma-135.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/keloids-36.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/porokeratosis-61.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/dermatofibroma-18.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/endometriosis-1.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/skin-tags-polyps-57.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/keratoacanthoma-144.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/skin-tags-polyps-17.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/chondrodermatitis-nodularis-59.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/syringoma-41.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/keratoacanthoma-167.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/chondrodermatitis-nodularis-33.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/keratoacanthoma-106.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/syringoma-37.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/chondrodermatitis-nodularis-15.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/sebaceous-hyperplasia-66.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/dermatofibroma-58.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/epidermal-nevus-50.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/keratoacanthoma-87.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/skin-tags-polyps-88.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/keratoacanthoma-83.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/nevus-sebaceous-26.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/neurofibromas-11.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/epidermal-nevus-48.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/epidermal-nevus-59.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/syringoma-34.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/pseudo-cyst-auricle-1.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/cylindroma-7.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/keratoacanthoma-105.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/porokeratosis-3.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/epidermal-cyst-106.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/skin-tags-polyps-95.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/porokeratosis-14.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/chondrodermatitis-nodularis-35.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/lichen-striatus-2.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/sebaceous-hyperplasia-94.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/dermatofibroma-20.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/porokeratosis-17.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/dermatofibroma-48.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/keratoacanthoma-11.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/dermatofibroma-136.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/chondrodermatitis-nodularis-78.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/20PilarCyst0825.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/dermatofibroma-31.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/dermatosis-papulosa-nigra-3.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/nevus-sebaceous-60.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/dermatosis-papulosa-nigra-2.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/20EpidermCystRuptured1.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/keratoacanthoma-184.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/sebaceous-hyperplasia-91.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/sebaceous-hyperplasia-33.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/keloids-10.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/keratoacanthoma-109.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/porokeratosis-12.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/epidermal-cyst-145.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/epidermal-cyst-185.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/keratoacanthoma-163.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/cylindroma-11.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/cylindroma-13.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/dermatofibroma-65.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/porokeratosis-99.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/porokeratosis-25.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/dermatofibroma-15.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/trichofolliculoma-4.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/dermatofibroma-13.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/epidermal-cyst-109.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/epidermal-nevus-35.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/nevus-sebaceous-52.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/epidermal-nevus-36.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/chondrodermatitis-nodularis-19.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/pilar-cyst-17.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/sebaceous-hyperplasia-10.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/dermatofibroma-131.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/epidermal-cyst-114.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/syringoma-43.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/sebaceous-hyperplasia-54.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/keratoacanthoma-82.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/epidermal-nevus-23.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/epidermal-cyst-141.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/20SebNevus0216.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/sebaceous-hyperplasia-43.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/keratoacanthoma-84.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/nevus-sebaceous-48.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/keloids-14.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/dermatofibroma-90.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/skin-tags-polyps-72.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/pilar-cyst-37.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/nevus-sebaceous-9.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/keratoacanthoma-12.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/epidermal-cyst-110.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/keratoacanthoma-141.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/keratoacanthoma-153.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/nevus-sebaceous-8.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/epidermal-cyst-171.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/neurofibromas-6.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/granular-cell-tumor-1.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/dermatofibroma-105.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/accessory-nipple-7.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/keratoacanthoma-155.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/skin-tags-polyps-2.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/connective-tissue-nevus-2.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/epidermal-nevus-63.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/dermatofibroma-78.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/dermatofibroma-91.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/fibromatosis-progressive-1.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/keratoacanthoma-180.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/nevus-sebaceous-63.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Benign_tumors/porokeratosis-41.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/Hand_0000108.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/download (21).jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1564349683136-77e08dba1ef7.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/6 (104).jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/71faHQo3nRL.AC_SX500.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/download (23).jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/pexels-photo-2295744.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1495012379376-194a416fcc5f.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/0_0_dongchengpeng_0042.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/0_0_baobeier_0020.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/hummingbird-bird-birds-349758.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/download (1) (10).jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/download (4).jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/47-masala-chai-canva-phpsbxpRf.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/premium_photo-1673455210352-ceb2a0214bc4.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/images (1) (13).jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/images (23).jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/premium_photo-1666237390552-dca0ad72629c.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/6 (32).jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1508859459823-38ea91d8f937.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/Hand_0005634.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/Hand_0000069.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/263_jpg.rf.862c9ecb7e95f1fb80d28226ee7849ca.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/shopping (6).jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/41jdLQwMw8L._AC_UF452452_FMjpg_.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/pexels-photo-5728612.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1563630381190-77c336ea545a.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1590741276397-5cb81c3bf8de.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/download (1) (9).jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/41gW1zQCDL._AC_UF452452_FMjpg_.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1534188753412-3e26d0d618d6.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/6 (25).jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/premium_photo-1668208363412-8f668417e44e.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/71GdxVHfymL.AC_SX500.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/download (26).jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/28.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1512373806263-ea7c704a1c16.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/254_jpg.rf.1d7ce799f366505919beb008b08be4ca.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/images (2) (9).jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/Hand_0000456.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/1705156-2008819274.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/images (1) (19).jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/Hand_0000212.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/0_0_gulinazha_0035.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/41klgn0zSmS._AC_UF226226_FMjpg_.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1590435026808-ec9a5b6632f9.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/bodymap_shoulder_1640.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/download (39).jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/112_jpg.rf.c4fe2a35b83a8a79622c941ca64e9552.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/214_jpg.rf.7e30201e5d7531031dfd18ce88691292.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/images (2) (16).jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/61KPQ1BKTkL._AC_UF452452_FMjpg_.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/0_0_caiyilin_0100.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1587334207407-deb137a955ba.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/6 (23).jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1533766837525-f6d19d32149a.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/319_jpg.rf.a13b6f6c611e192a41fd122adfb196e7.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/download (17).jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/Hand_0000510.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/0_0_anhu_0216.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1557242836-b5ab8bb0ebb4.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/premium_photo-1669725687138-f570eda7393c.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/images (2) (12).jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/download (1) (20).jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1570857502809-08184874388e.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/Hand_0000090.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/Hand_0000634.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/exter-exterior-right-front-three-quarter-292.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1612258644055-d0ed1fa446f7.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1607992922515-7e38329e65d4.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/261_jpg.rf.e7b99f5b1f553ebcd7184e2d71d23013.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/hurikan-440-right-side-view2.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/images (2) (5).jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/264_jpg.rf.d3b3be7933ce1f3458ac8473e1616275.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/Hand_0010965.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/108_jpg.rf.18c4dc99bcad0d6f2ab52a9ca21d54ea.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/pexels-photo-6354993.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/119_jpg.rf.7f9b75122f1551f5e47b3575a479b550.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1556910096-6f5e72db6803.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1603251579431-8041402bdeda.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1577703691096-6de1c5c3fa85.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1510924199351-4e9d94df18a6.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/104_jpg.rf.cfcee7099c3a287e4db78ed28dae4576.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1509628061459-1328d06c2ced.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/premium_photo-1666361680422-dde2b34f91cb.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/Hand_0000008.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1601050690294-397f3c324515.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/51l0dg4m9AL._AC_UF452452_FMjpg_.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/download (5).jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/0_0_cengyongti_0042.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/226_jpg.rf.f9b1098c7f5e0e34ebccf20d89ec6f7b.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/71oZ1-QYomL.AC_SX500.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/bodymap_chest_1640.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1503926359680-9ddd5b2bcbdc.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/71JfqFSkZfL.AC_SX500.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/Hand_0007107.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/6 (37).jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/download (10).jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1610444833203-69c3b23321a0.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/6 (64).jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/221_jpg.rf.becc816f0c3f732a98611e9c8bc81ee2.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/husqvarna-svartpilen-401.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/images (2) (30).jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1536427824649-fbf2e4a33d40.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/71OHGRMj2FL._AC_UF226226_FMjpg_.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/6 (35).jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/Hand_0000424.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/81jBJREzITL.AC_SX500.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/pexels-photo-1108099.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/images (30).jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/Hand_0000542.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/21xJS3XnQ7L._AC_UF452452_FMjpg_.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/331---Copy_jpg.rf.0196b1d606a13f84d6f83a5f36eeaef0.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1627787489784-4abd690c03c2.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/0_0_cengyongti_0063.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/david-dibert-510.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/6 (100).jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1518495973542-4542c06a5843.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/54.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/10-Best-Hot-Hair-Brushes.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/grey-crowned-crane-bird-crane-animal-458533.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/chiruposter13082022.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/6 (26).jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1590418270220-243198c900cc.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1592335445215-aaf2b5fe58c0.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/Hand_0000633.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/Hand_0000594.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/Hand_0000615.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/images (15).jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1559746261-8e366f3b045f.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/31yGVRbW6TL._AC_UF226226_FMjpg_.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/Hand_0000202.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1544779493-aa344a6ddaac.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1484024091473-858a1e7ece52.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1562569633-622303bafef5.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/pexels-photo-97533.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/wrev1ljvQ6KlfyljCQG0_lion.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1551946581-f7a62cd2f00b.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1523949538449-87dd068b65e6.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/download (1) (27).jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1546868871-7041f2a55e12.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/1049382-HomeSN-380x500-PendantLights._V507977761_.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/191_jpg.rf.64616d53dbebca7b92cfc1c8e1c73483.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/61fPH47Hd0L._AC_UL480_QL65_.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/images (2) (22).jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/premium_photo-1666777253038-e66184b5cb16.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/137_jpg.rf.4f4070ae7d7a4d05b3d29d89845ffd58.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1552966722-0a3e28ba2735.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/download (50).jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/Hand_0000552.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1587049633312-d628ae50a8ae.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1586617356423-52763004deac.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/Hand_0006359.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1675506692446-d8dc4ce5047c.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/6 (70).jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/Hand_0005704.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1444464666168-49d633b86797.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1603632088148-3680d7e5dda2.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/184_jpg.rf.a289f154f02fdae79673360c0fa67386.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/91lOyZb3J1L.AC_SX500.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1581655353564-df123a1eb820.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1459262838948-3e2de6c1ec80.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/41_jpg.rf.b0a0db63329a956e3d5de18316d7d627.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/51DuvgA2MvL._AC_UF226226_FMjpg_.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/71XqQU15NfL.AC_SX500.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/hunter-350-right-front-three-quarter2.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/6 (1).jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/download (22).jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/Hand_0010193.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/41dD1IQ4Q2L._AC_UF452452_FMjpg_.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/0_0_dongchengpeng_0020.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1558387883-4bd9b06312d6.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1613318282885-2168d00a8d2e.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/274_jpg.rf.f64b24c409acdf3489a1e9fbe5106667.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1571575173700-afb9492e6a50.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/41LkX7bHnPL.AC_SX250.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1580200213184-c6aad1610aec.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/167_jpg.rf.8d7c2e6fc6e7b0a1b7c092ae16782c13.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/41qwfh7XL._AC_UL320_.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1527161153332-99adcc6f2966.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/image2.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1519817914152-22d216bb9170.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/51ZF5d5LFwL._AC_UF452452_FMjpg_.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1561780535-118e36e56095.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/31xzLRAR2SL._AC_UF452452_FMjpg_.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/hunter-350-right-front-three-quarter3.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1620196244888-d31ff5bbf163.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/photo-1616515998334-5f157710a178.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Unknown_Normal/81y6Q5R0rjL.AC_SX500.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-foot-webs-30.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-versicolor-18.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-versicolor-168.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-body-164.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-groin-26.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-body-15.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-versicolor-79.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-face-9.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tincorp6__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-body-109.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-primary-lesion-28.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-versicolor-19.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-palm-22.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-groin-6.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tincorp5__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDE2XQ.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-versicolor-187.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-groin-33.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-body-184.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-primary-lesion-46.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-body-114.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-palm-2.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-groin-38.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tincorp18__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-body-152.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-body-101.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-groin-67.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-scalp-47.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-palm-34.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-palm-25.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-primary-lesion-3.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-foot-dorsum-61.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-foot-plantar-48.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-scalp-32.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-foot-webs-25.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-body-167.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-hand-dorsum-66.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-groin-75.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/13TineaGroin143.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-incognito-44.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-foot-dorsum-22.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-incognito-11.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-foot-dorsum-23.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-incognito-51.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-foot-dorsum-19.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-foot-plantar-10.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-body-176.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-foot-dorsum-25.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-incognito-13.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-scalp-50.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-foot-plantar-50.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-body-132.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-groin-72.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-primary-lesion-64.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-groin-91.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-palm-10.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-body-106.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-body-17.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-hand-dorsum-16.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-groin-87.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-versicolor-159.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-foot-plantar-44.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-incognito-47.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-groin-109.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-versicolor-186.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinped19__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsInkiLDdd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-scalp-7.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-body-162.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-groin-64.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-foot-webs-80.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-body-98.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-versicolor-104.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-foot-plantar-30.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/13tineaCorporis0808054.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tincorp1__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDRd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-hand-dorsum-25.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-foot-webs-23.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-groin-112.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-body-133.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-palm-40.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-face-13.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-beard-1.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-groin-89.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-versicolor-87.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-foot-dorsum-41.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-body-165.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-primary-lesion-63.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-beard-4.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-versicolor-137.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/13TineaGroin34.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-foot-webs-49.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-foot-webs-53.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-face-55.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-incognito-20.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-versicolor-100.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinped7__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsInkiLDM2XQ.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-body-9.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-foot-dorsum-27.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-foot-webs-17.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-versicolor-185.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-beard-3.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-face-17.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Tinea/tinea-primary-lesion-53.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-hand-147.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-hand-183.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-scrotum-2.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-hand-135.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-nummular-113.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-nummular-195.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-acute-23.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/05atopic060704.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-face-9.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/05Atopic020203.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-face-10.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-face-2.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-foot-37.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/05atopic0411055.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-subacute-1.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-lids-11.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-subacute-36.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-nummular-189.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-foot-43.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-chronic-7.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-nummular-190.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-vulva-6.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-hand-136.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-fingertips-41.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-impetiginized-11.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-hand-192.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-subacute-33.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-fingertips-11.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-trunk-generalized-20.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-foot-25.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-fingertips-98.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-hand-122.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-foot-56.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-hand-170.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/05AtopicFeet.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-acute-1.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-areola-17.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-nummular-88.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-asteatotic-1.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-foot-72.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-lids-1.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/3Eczema3-021.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-arms-7.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-foot-57.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-fingertips-24.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-nummular-17.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-areola-6.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-chronic-6.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-foot-30.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-foot-32.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-fingertips-38.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-subacute-90.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-fingertips-142.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/03Eczema0310.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-nummular-126.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-fingertips-66.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-hand-187.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-foot-27.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-hand-169.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-hand-166.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-foot-53.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-subacute-63.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test/Eczema/eczema-trunk-generalized-28.jpeg
# ...
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/2523__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsInkiLDM2XQ.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/dle-scalp3__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsInkiLDM2XQ.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-39.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-sc4__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDIzXQ.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/2538__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsInkiLDg1XQ.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-73.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/2554__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-acute-8.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/2573__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-75.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/2556__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDBd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-62.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-122.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-143.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-acute-5.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/discoid-lupus-20__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsInkiLDg1XQ.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/2551__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsInkiLDZd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-54.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-69.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-acute-3.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/discoid-lupus-21__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsInkiLDg1XQ.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-72.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-59.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-65.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-133.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/2519__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsInkiLDM2XQ.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/subacute-lupus-04__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd.JPG.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-140.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-20.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-103.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/2520__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsInkiLDM2XQ.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-acute-27.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-11.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/discoid-lupus-06__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-145.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-subacute-4.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-subacute-3.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/subacute-lupus-08__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd.JPG.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-119.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-93.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-pann__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-acute-49.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/subacute-lupus-21__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd.JPG.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-facial__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsInkiLDc5XQ.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-acute-58.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-10.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/2548__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-acute-9.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-91.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/discoid-lupus-14__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDE5XQ.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/discoid-lupus-12__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/sle-58__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-acute-45.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-24.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-profundus2__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsInkiLDg1XQ.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-33.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-acute-50.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/sle-10__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/sle-29__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/2553__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-107.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-115.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-35.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-109.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-sc2__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-neonatal-2.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/plaque-le2__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsInkiLDJd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-46.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-129.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/subacute-lupus-12__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd.JPG.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-subacute-15.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/2527__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsInkiLDM2XQ.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-fingers__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-47.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/2558__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsInkiLDZd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/discoid-lupus-16__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/2568__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDE5XQ.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/dle-scalp2__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsInkiLDM2XQ.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/subacute-lupus-10__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsInkiLDg1XQ.JPG.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/dle-scalp__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsInkiLDZd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/2516__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsInkiLDM2XQ.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-52.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-40.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/2525__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsInkiLDM2XQ.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-13.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/2544__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-subacute-14.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/dle-lip__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsInkiLDZd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-acute-13.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/discoid-lupus-05__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-63.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/plaque-le__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/discoid-lupus-17__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/2531__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDE4XQ.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/2537__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-acute-36.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-136.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-profundus__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/2555__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDBd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/discoid-lupus-11__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-subacute-8.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-subacute-12.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-34.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-106.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/2515__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsInkiLDM2XQ.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-78.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-tum3-s__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-neonatal-1.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-16.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/2560__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsInkiLDZd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-36.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-acute-44.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-105.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-vasculitis__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-acute-39.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/htrophicle__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-acute-57.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-acute-24.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-9.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-85.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/2542__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-53.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-128.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-27.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/subacute-lupus-16__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsInkiLDg1XQ.JPG.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-49.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-87.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/discoid-lupus-18__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/subacute-lupus-15__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsInkiLDg1XQ.JPG.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-56.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-sc3__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsInkiLDZd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-acute-12.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-bullous__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chilb__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsInkiLDM2XQ.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/discoid-lupus-19__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-18.jpeg
# /kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train/Lupus/lupus-chronic-cutaneous-104.jpeg

# %%
import torch
import torchvision

from torch import nn
from torchvision import transforms

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
dataset_path = os.listdir('/kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test')
print (dataset_path)  #what kinds of classes are in this dataset

print("Types of classes labels found: ", len(dataset_path))
# Out:
# ['Benign_tumors', 'Unknown_Normal', 'Tinea', 'Eczema', 'Actinic_Keratosis', 'Vascular_Tumors', 'Acne', 'Infestations_Bites', 'Rosacea', 'Seborrh_Keratoses', 'Moles', 'Vitiligo', 'SkinCancer', 'Vasculitis', 'Lichen', 'Candidiasis', 'DrugEruption', 'Sun_Sunlight_Damage', 'Bullous', 'Warts', 'Psoriasis', 'Lupus']
# Types of classes labels found:  22

# %%
import random
pretrained_vit_weights = torchvision.models.ViT_B_16_Weights.DEFAULT 

# 2. Setup a ViT model instance with pretrained weights
pretrained_vit = torchvision.models.vit_b_16(weights=pretrained_vit_weights).to(device)

# 3. Freeze the base parameters
for parameter in pretrained_vit.parameters():
    parameter.requires_grad = False
    
# 4. Change the classifier head 
class_names = ['Benign_tumors', 'Unknown_Normal', 'Tinea', 'Eczema', 'Actinic_Keratosis', 'Vascular_Tumors',
               'Acne', 'Infestations_Bites', 'Rosacea', 'Seborrh_Keratoses', 'Moles', 'Vitiligo', 'SkinCancer',
               'Vasculitis', 'Lichen', 'Candidiasis', 'DrugEruption', 'Sun_Sunlight_Damage', 'Bullous', 'Warts', 'Psoriasis', 'Lupus']

def set_seeds(seed: int=42):
    # Set the seed for general torch operations
    torch.manual_seed(seed)
    # Set the seed for CUDA torch operations (ones that happen on the GPU)
    torch.cuda.manual_seed(seed)


set_seeds()
pretrained_vit.heads = nn.Linear(in_features=768, out_features=len(class_names)).to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/vit_b_16-c867db91.pth" to /root/.cache/torch/hub/checkpoints/vit_b_16-c867db91.pth
# 100%|██████████| 330M/330M [00:01<00:00, 229MB/s]

# %%
from torchinfo import summary

# Print a summary using torchinfo (uncomment for actual output)
summary(model=pretrained_vit, 
        input_size=(8, 3, 224, 224), # (batch_size, color_channels, height, width)
        # col_names=["input_size"], # uncomment for smaller output
        col_names=["input_size", "output_size", "num_params", "trainable"],
        col_width=20,
        row_settings=["var_names"]
)
# Out:
# ============================================================================================================================================
# Layer (type (var_name))                                      Input Shape          Output Shape         Param #              Trainable
# ============================================================================================================================================
# VisionTransformer (VisionTransformer)                        [8, 3, 224, 224]     [8, 22]              768                  Partial
# ├─Conv2d (conv_proj)                                         [8, 3, 224, 224]     [8, 768, 14, 14]     (590,592)            False
# ├─Encoder (encoder)                                          [8, 197, 768]        [8, 197, 768]        151,296              False
# │    └─Dropout (dropout)                                     [8, 197, 768]        [8, 197, 768]        --                   --
# │    └─Sequential (layers)                                   [8, 197, 768]        [8, 197, 768]        --                   False
# │    │    └─EncoderBlock (encoder_layer_0)                   [8, 197, 768]        [8, 197, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_1)                   [8, 197, 768]        [8, 197, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_2)                   [8, 197, 768]        [8, 197, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_3)                   [8, 197, 768]        [8, 197, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_4)                   [8, 197, 768]        [8, 197, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_5)                   [8, 197, 768]        [8, 197, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_6)                   [8, 197, 768]        [8, 197, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_7)                   [8, 197, 768]        [8, 197, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_8)                   [8, 197, 768]        [8, 197, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_9)                   [8, 197, 768]        [8, 197, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_10)                  [8, 197, 768]        [8, 197, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_11)                  [8, 197, 768]        [8, 197, 768]        (7,087,872)          False
# │    └─LayerNorm (ln)                                        [8, 197, 768]        [8, 197, 768]        (1,536)              False
# ├─Linear (heads)                                             [8, 768]             [8, 22]              16,918               True
# ============================================================================================================================================
# Total params: 85,815,574
# Trainable params: 16,918
# Non-trainable params: 85,798,656
# Total mult-adds (G): 1.38
# ============================================================================================================================================
# Input size (MB): 4.82
# Forward/backward pass size (MB): 832.69
# Params size (MB): 229.26
# Estimated Total Size (MB): 1066.76
# ============================================================================================================================================

# %%
train_dir = '/kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/train'
test_dir = '/kaggle/input/skindiseasedataset/SkinDisease/SkinDisease/test'

# %%
pretrained_vit_transforms = pretrained_vit_weights.transforms()
print(pretrained_vit_transforms)
# Out:
# ImageClassification(
#     crop_size=[224]
#     resize_size=[256]
#     mean=[0.485, 0.456, 0.406]
#     std=[0.229, 0.224, 0.225]
#     interpolation=InterpolationMode.BILINEAR
# )

# %%
import os

from torchvision import datasets, transforms
from torch.utils.data import DataLoader

NUM_WORKERS = os.cpu_count()

def create_dataloaders(
    train_dir: str, 
    test_dir: str, 
    transform: transforms.Compose, 
    batch_size: int, 
    num_workers: int=NUM_WORKERS
):

  # Use ImageFolder to create dataset(s)
  train_data = datasets.ImageFolder(train_dir, transform=transform)
  test_data = datasets.ImageFolder(test_dir, transform=transform)

  # Get class names
  class_names = train_data.classes

  # Turn images into data loaders
  train_dataloader = DataLoader(
      train_data,
      batch_size=batch_size,
      shuffle=True,
      num_workers=num_workers,
      pin_memory=True,
  )
  test_dataloader = DataLoader(
      test_data,
      batch_size=batch_size,
      shuffle=False,
      num_workers=num_workers,
      pin_memory=True,
  )

  return train_dataloader, test_dataloader, class_names

# %%
train_dataloader_pretrained, test_dataloader_pretrained, class_names = create_dataloaders(train_dir=train_dir,
                                                                                                     test_dir=test_dir,
                                                                                                     transform=pretrained_vit_transforms,
                                                                                                     batch_size=32)

# %%
import torch

from tqdm.auto import tqdm
from typing import Dict, List, Tuple

def train(model: torch.nn.Module, 
          train_dataloader: torch.utils.data.DataLoader, 
          test_dataloader: torch.utils.data.DataLoader, 
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module,
          epochs: int,
          device: torch.device) -> Dict[str, List]:
    # Create empty results dictionary
    results = {"train_loss": [],
               "train_acc": [],
               "test_loss": [],
               "test_acc": []
    }
    
    # Make sure model on target device
    model.to(device)

    # Loop through training and testing steps for a number of epochs
    for epoch in tqdm(range(epochs)):
        train_loss, train_acc = train_step(model=model,
                                          dataloader=train_dataloader,
                                          loss_fn=loss_fn,
                                          optimizer=optimizer,
                                          device=device)
        test_loss, test_acc = test_step(model=model,
          dataloader=test_dataloader,
          loss_fn=loss_fn,
          device=device)

        # Print out what's happening
        print(
          f"Epoch: {epoch+1} | "
          f"train_loss: {train_loss:.4f} | "
          f"train_acc: {train_acc:.4f} | "
          f"test_loss: {test_loss:.4f} | "
          f"test_acc: {test_acc:.4f}"
        )

        # Update results dictionary
        results["train_loss"].append(train_loss)
        results["train_acc"].append(train_acc)
        results["test_loss"].append(test_loss)
        results["test_acc"].append(test_acc)

    # Return the filled results at the end of the epochs
    return results

# %%
def train_step(model: torch.nn.Module, 
               dataloader: torch.utils.data.DataLoader, 
               loss_fn: torch.nn.Module, 
               optimizer: torch.optim.Optimizer,
               device: torch.device) -> Tuple[float, float]:
    
    # Put model in train mode
    model.train()

    # Setup train loss and train accuracy values
    train_loss, train_acc = 0, 0

    # Loop through data loader data batches
    for batch, (X, y) in enumerate(dataloader):
        # Send data to target device
        X, y = X.to(device), y.to(device)

        # 1. Forward pass
        y_pred = model(X)

        # 2. Calculate  and accumulate loss
        loss = loss_fn(y_pred, y)
        train_loss += loss.item() 

        # 3. Optimizer zero grad
        optimizer.zero_grad()

        # 4. Loss backward
        loss.backward()

        # 5. Optimizer step
        optimizer.step()

        # Calculate and accumulate accuracy metric across all batches
        y_pred_class = torch.argmax(torch.softmax(y_pred, dim=1), dim=1)
        train_acc += (y_pred_class == y).sum().item()/len(y_pred)

    # Adjust metrics to get average loss and accuracy per batch 
    train_loss = train_loss / len(dataloader)
    train_acc = train_acc / len(dataloader)
    return train_loss, train_acc

# %%
def test_step(model: torch.nn.Module, 
              dataloader: torch.utils.data.DataLoader, 
              loss_fn: torch.nn.Module,
              device: torch.device) -> Tuple[float, float]:
    
    # Put model in eval mode
    model.eval() 

    # Setup test loss and test accuracy values
    test_loss, test_acc = 0, 0

    # Turn on inference context manager
    with torch.inference_mode():
        # Loop through DataLoader batches
        for batch, (X, y) in enumerate(dataloader):
            # Send data to target device
            X, y = X.to(device), y.to(device)

            # 1. Forward pass
            test_pred_logits = model(X)

            # 2. Calculate and accumulate loss
            loss = loss_fn(test_pred_logits, y)
            test_loss += loss.item()

            # Calculate and accumulate accuracy
            test_pred_labels = test_pred_logits.argmax(dim=1)
            test_acc += ((test_pred_labels == y).sum().item()/len(test_pred_labels))

    # Adjust metrics to get average loss and accuracy per batch 
    test_loss = test_loss / len(dataloader)
    test_acc = test_acc / len(dataloader)
    return test_loss, test_acc

# %%
# Create optimizer and loss function
optimizer = torch.optim.AdamW(params=pretrained_vit.parameters(), lr=3e-4, weight_decay=1e-4)
loss_fn = torch.nn.CrossEntropyLoss()

# Train the classifier head of the pretrained ViT feature extractor model
set_seeds()
pretrained_vit_results = train(model=pretrained_vit,
                                      train_dataloader=train_dataloader_pretrained,
                                      test_dataloader=test_dataloader_pretrained,
                                      optimizer=optimizer,
                                      loss_fn=loss_fn,
                                      epochs=30,
                                      device=device)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 2.3121 | train_acc: 0.3281 | test_loss: 1.9663 | test_acc: 0.4301
# Epoch: 2 | train_loss: 1.8387 | train_acc: 0.4695 | test_loss: 1.7491 | test_acc: 0.4971
# Epoch: 3 | train_loss: 1.6581 | train_acc: 0.5134 | test_loss: 1.6480 | test_acc: 0.5149
# Epoch: 4 | train_loss: 1.5480 | train_acc: 0.5414 | test_loss: 1.5768 | test_acc: 0.5316
# Epoch: 5 | train_loss: 1.4711 | train_acc: 0.5576 | test_loss: 1.5237 | test_acc: 0.5360
# Epoch: 6 | train_loss: 1.4093 | train_acc: 0.5782 | test_loss: 1.4835 | test_acc: 0.5527
# Epoch: 7 | train_loss: 1.3621 | train_acc: 0.5920 | test_loss: 1.4558 | test_acc: 0.5622
# Epoch: 8 | train_loss: 1.3215 | train_acc: 0.6022 | test_loss: 1.4371 | test_acc: 0.5616
# Epoch: 9 | train_loss: 1.2856 | train_acc: 0.6138 | test_loss: 1.4192 | test_acc: 0.5584
# Epoch: 10 | train_loss: 1.2550 | train_acc: 0.6237 | test_loss: 1.4055 | test_acc: 0.5718
# Epoch: 11 | train_loss: 1.2299 | train_acc: 0.6286 | test_loss: 1.3900 | test_acc: 0.5629
# Epoch: 12 | train_loss: 1.2042 | train_acc: 0.6383 | test_loss: 1.3723 | test_acc: 0.5756
# Epoch: 13 | train_loss: 1.1813 | train_acc: 0.6428 | test_loss: 1.3609 | test_acc: 0.5788
# Epoch: 14 | train_loss: 1.1618 | train_acc: 0.6527 | test_loss: 1.3540 | test_acc: 0.5750
# Epoch: 15 | train_loss: 1.1434 | train_acc: 0.6577 | test_loss: 1.3484 | test_acc: 0.5756
# Epoch: 16 | train_loss: 1.1273 | train_acc: 0.6597 | test_loss: 1.3387 | test_acc: 0.5903
# Epoch: 17 | train_loss: 1.1108 | train_acc: 0.6684 | test_loss: 1.3354 | test_acc: 0.5807
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-71e5523cc405> in <cell line: 7>()
#       5 # Train the classifier head of the pretrained ViT feature extractor model
#       6 set_seeds()
# ----> 7 pretrained_vit_results = train(model=pretrained_vit,
#       8                                       train_dataloader=train_dataloader_pretrained,
#       9                                       test_dataloader=test_dataloader_pretrained,
#
# <ipython-input-11-7546d0898c30> in train(model, train_dataloader, test_dataloader, optimizer, loss_fn, epochs, device)
#      23     # Loop through training and testing steps for a number of epochs
#      24     for epoch in tqdm(range(epochs)):
# ---> 25         train_loss, train_acc = train_step(model=model,
#      26                                           dataloader=train_dataloader,
#      27                                           loss_fn=loss_fn,
#
# <ipython-input-12-c3c9c7717a97> in train_step(model, dataloader, loss_fn, optimizer, device)
#      21         # 2. Calculate  and accumulate loss
#      22         loss = loss_fn(y_pred, y)
# ---> 23         train_loss += loss.item()
#      24
#      25         # 3. Optimizer zero grad
#
# KeyboardInterrupt:

# %%
def pred_and_plot_image(
    model: torch.nn.Module,
    image_path: str,
    class_names: List[str] = None,
    transform=None,
    device: torch.device = "cuda" if torch.cuda.is_available() else "cpu",
):
    

    # 1. Load in image and convert the tensor values to float32
    target_image = torchvision.io.read_image(str(image_path)).type(torch.float32)

    # 2. Divide the image pixel values by 255 to get them between [0, 1]
    target_image = target_image / 255.0

    # 3. Transform if necessary
    if transform:
        target_image = transform(target_image)

    # 4. Make sure the model is on the target device
    model.to(device)

    # 5. Turn on model evaluation mode and inference mode
    model.eval()
    with torch.inference_mode():
        # Add an extra dimension to the image
        target_image = target_image.unsqueeze(dim=0)

        # Make a prediction on image with an extra dimension and send it to the target device
        target_image_pred = model(target_image.to(device))

    # 6. Convert logits -> prediction probabilities (using torch.softmax() for multi-class classification)
    target_image_pred_probs = torch.softmax(target_image_pred, dim=1)

    # 7. Convert prediction probabilities -> prediction labels
    target_image_pred_label = torch.argmax(target_image_pred_probs, dim=1)

    # 8. Plot the image alongside the prediction and prediction probability
    plt.imshow(
        target_image.squeeze().permute(1, 2, 0)
    )  # make sure it's the right size for matplotlib
    if class_names:
        title = f"Pred: {class_names[target_image_pred_label.cpu()]} | Prob: {target_image_pred_probs.max().cpu():.3f}"
    else:
        title = f"Pred: {target_image_pred_label} | Prob: {target_image_pred_probs.max().cpu():.3f}"
    plt.title(title)
    plt.axis(False)

# %%
def plot_loss_curves(results):
    loss = results["train_loss"]
    test_loss = results["test_loss"]

    accuracy = results["train_acc"]
    test_accuracy = results["test_acc"]

    epochs = range(len(results["train_loss"]))

    plt.figure(figsize=(15, 7))

    # Plot loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, loss, label="train_loss")
    plt.plot(epochs, test_loss, label="test_loss")
    plt.title("Loss")
    plt.xlabel("Epochs")
    plt.legend()

    # Plot accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, accuracy, label="train_accuracy")
    plt.plot(epochs, test_accuracy, label="test_accuracy")
    plt.title("Accuracy")
    plt.xlabel("Epochs")
    plt.legend()

# %%
plot_loss_curves(pretrained_vit_results)

# %%
from PIL import Image

# Define transformations (same as training)
image_transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize to match ViT input size
    transforms.ToTensor(),  # Convert image to tensor
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])  # Normalize
])

# Function to predict and plot an image
def pred_and_plot_image(model, image_path, class_names, device="cuda"):
    model.eval()  # Set to evaluation mode

    # Load image
    image = Image.open(image_path).convert("RGB")
    transformed_image = image_transform(image).unsqueeze(0).to(device)  # Apply transformations & add batch dimension

    # Perform inference
    with torch.inference_mode():
        y_pred = model(transformed_image)

    # Get predicted class
    y_pred_probs = torch.softmax(y_pred, dim=1)
    y_pred_label = torch.argmax(y_pred_probs, dim=1).item()
    
    print(f"Predicted class: {class_names[y_pred_label]} (Confidence: {y_pred_probs[0][y_pred_label]:.2f})")

# %%
# Setup custom image path
custom_image_path = "/kaggle/input/unseen-data/PXL_20250208_1229178382.jpg"

# Predict on custom image
pred_and_plot_image(model=pretrained_vit,
                    image_path=custom_image_path,
                    class_names=class_names)

# %%
# Setup custom image path
custom_image_path = "/kaggle/input/unseen-data/images.jpg"

# Predict on custom image
pred_and_plot_image(model=pretrained_vit,
                    image_path=custom_image_path,
                    class_names=class_names)
